# %%
import pandas as pd

# Training files
train = pd.read_csv('Train-1542865627584.csv')
train_beneficiary = pd.read_csv('Train_Beneficiarydata-1542865627584.csv')
train_inpatient = pd.read_csv('Train_Inpatientdata-1542865627584.csv')
train_outpatient = pd.read_csv('Train_Outpatientdata-1542865627584.csv')

# Test files
test = pd.read_csv('Test-1542969243754.csv')
test_beneficiary = pd.read_csv('Test_Beneficiarydata-1542969243754.csv')
test_inpatient = pd.read_csv('Test_Inpatientdata-1542969243754.csv')
test_outpatient = pd.read_csv('Test_Outpatientdata-1542969243754.csv')

# %%
# Look at the top rows of each dataset
print("Train:")
display(train.head())

print("Beneficiary:")
display(train_beneficiary.head())

print("Inpatient:")
display(train_inpatient.head())

print("Outpatient:")
display(train_outpatient.head())
# Out:
# Train:
#    Provider PotentialFraud
# 0  PRV51001             No
# 1  PRV51003            Yes
# 2  PRV51004             No
# 3  PRV51005            Yes
# 4  PRV51007             No
# Beneficiary:
#       BeneID         DOB  DOD  Gender  Race RenalDiseaseIndicator  State  \
# 0  BENE11001  1943-01-01  NaN       1     1                     0     39
# 1  BENE11002  1936-09-01  NaN       2     1                     0     39
# 2  BENE11003  1936-08-01  NaN       1     1                     0     52
# 3  BENE11004  1922-07-01  NaN       1     1                     0     39
# 4  BENE11005  1935-09-01  NaN       1     1                     0     24
#
#    County  NoOfMonths_PartACov  NoOfMonths_PartBCov  ...  \
# 0     230                   12                   12  ...
# 1     280                   12                   12  ...
# 2     590                   12                   12  ...
# 3     270                   12                   12  ...
# ...

# %%
# Check the class distribution of the target
train['PotentialFraud'].value_counts(normalize=True)
# Out:
# PotentialFraud
# No     0.90647
# Yes    0.09353
# Name: proportion, dtype: float64

# %%
# Merge inpatient + outpatient + train on Provider
all_claims = pd.concat([train_inpatient, train_outpatient])
merged = pd.merge(all_claims, train, on='Provider', how='left')

# Group by Provider: Total reimbursement
reimb_by_provider = merged.groupby('Provider')['InscClaimAmtReimbursed'].sum().reset_index()
reimb_by_provider.columns = ['Provider', 'TotalReimbursement']

# Look at top reimbursed providers
reimb_by_provider.sort_values('TotalReimbursement', ascending=False).head(10)
# Out:
#       Provider  TotalReimbursement
# 818   PRV52019             5996050
# 3557  PRV55462             4713830
# 4446  PRV56560             3212000
# 2705  PRV54367             3133880
# 3000  PRV54742             2969530
# 3358  PRV55209             2914700
# 2176  PRV53706             2831940
# 4334  PRV56416             2744870
# 3373  PRV55230             2612740
# 1071  PRV52340             2540130

# %%
# Count claims per provider
inpatient_claims = train_inpatient['Provider'].value_counts().reset_index()
inpatient_claims.columns = ['Provider', 'InpatientClaimCount']

outpatient_claims = train_outpatient['Provider'].value_counts().reset_index()
outpatient_claims.columns = ['Provider', 'OutpatientClaimCount']

# Merge both counts
claim_counts = pd.merge(inpatient_claims, outpatient_claims, on='Provider', how='outer').fillna(0)
claim_counts['TotalClaims'] = claim_counts['InpatientClaimCount'] + claim_counts['OutpatientClaimCount']

# Show top providers by claim volume
top_claims = claim_counts.sort_values(by='TotalClaims', ascending=False).head(10)
top_claims
# Out:
#       Provider  InpatientClaimCount  OutpatientClaimCount  TotalClaims
# 363   PRV51459                  0.0                8240.0       8240.0
# 2250  PRV53797                  0.0                4739.0       4739.0
# 455   PRV51574                  0.0                4444.0       4444.0
# 2335  PRV53918                  0.0                3588.0       3588.0
# 3113  PRV54895                  3.0                3433.0       3436.0
# 3363  PRV55215                143.0                3250.0       3393.0
# 853   PRV52064                 38.0                2806.0       2844.0
# 4004  PRV56011                  0.0                2833.0       2833.0
# 3195  PRV55004                  3.0                2396.0       2399.0
# 5032  PRV57306                  0.0                2315.0       2315.0

# %%
# Ensure chronic condition columns are numeric
for col in chronic_cols:
    claims_with_fraud_label[col] = pd.to_numeric(claims_with_fraud_label[col], errors='coerce')

# Calculate average chronic conditions per provider
provider_chronic_avg = claims_with_fraud_label.groupby('Provider')[chronic_cols].mean()

# Add fraud label for each provider
provider_labels = claims_with_fraud_label[['Provider', 'PotentialFraud']].drop_duplicates()
provider_chronic_avg = provider_chronic_avg.merge(provider_labels, on='Provider')

# Show average chronic conditions grouped by fraud status
provider_chronic_avg.groupby('PotentialFraud')[chronic_cols].mean().T
# Out:
# PotentialFraud                         No       Yes
# ChronicCond_Alzheimer            1.598213  1.572228
# ChronicCond_Heartfailure         1.409415  1.368806
# ChronicCond_KidneyDisease        1.585271  1.526518
# ChronicCond_Cancer               1.847343  1.840895
# ChronicCond_ObstrPulmonary       1.681110  1.639226
# ChronicCond_Depression           1.565327  1.542251
# ChronicCond_Diabetes             1.295383  1.266621
# ChronicCond_IschemicHeart        1.236440  1.212042
# ChronicCond_Osteoporasis         1.680172  1.670657
# ChronicCond_rheumatoidarthritis  1.693022  1.670399
# ChronicCond_stroke               1.896935  1.880186

# %%
import sys
# !{sys.executable} -m pip install matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 36.4 MB/s eta 0:00:0000:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 19.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 22.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━ 3/7 [fonttools]  WARNING: The scripts fonttools, pyftmerge, pyftsubset and ttx are installed in '/Library/Frameworks/Python.framework/Versions/3.13/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [matplotlib]7 [matplotlib]
# ...

# %%
# Recalculate and assign the chronic condition averages to a variable
chronic_means = provider_chronic_avg.groupby('PotentialFraud')[chronic_cols].mean()

# Plotting
import matplotlib.pyplot as plt

# Transpose for plotting
plot_data = chronic_means.T

# Plot
ax = plot_data.plot(kind='bar', figsize=(12, 6))
plt.title('Average Chronic Conditions by Fraud Status')
plt.xlabel('Chronic Condition')
plt.ylabel('Average (1 = Yes, 2 = No)')
plt.xticks(rotation=45, ha='right')
plt.legend(title='PotentialFraud')
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Combine all diagnosis code columns
diag_cols = ['ClmDiagnosisCode_1', 'ClmDiagnosisCode_2', 'ClmDiagnosisCode_3',
             'ClmDiagnosisCode_4', 'ClmDiagnosisCode_5', 'ClmDiagnosisCode_6',
             'ClmDiagnosisCode_7', 'ClmDiagnosisCode_8', 'ClmDiagnosisCode_9', 'ClmDiagnosisCode_10']

all_diag = claims_with_fraud_label[diag_cols].values.ravel()
all_diag = pd.Series(all_diag)
top_diag = all_diag.value_counts().dropna().head(10)

# Plot
plt.figure(figsize=(10, 6))
sns.barplot(x=top_diag.values, y=top_diag.index, palette='Blues_d')
plt.title("Top 10 Most Frequent Diagnosis Codes")
plt.xlabel("Frequency")
plt.ylabel("Diagnosis Code")
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 import seaborn as sns
#       2 import matplotlib.pyplot as plt
#       4 # Combine all diagnosis code columns
#
# ModuleNotFoundError: No module named 'seaborn'
